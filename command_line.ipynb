# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Cross-Organizational-Continual-Learning/experiments"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Cross-Organizational-Continual-Learning/experiments

# %%
# !chmod +x continual_ben_hul_sll_slh_gol_tcp.sh

# %%
# !./continual_ben_hul_sll_slh_gol_tcp.sh
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#
# Resampling training data...
# Reducing DoS-Hulk data from 298867 to 278104 samples
# Finished Undersampling
# Targeting 139052 samples for each minority class
# Finished Oversampling
# Original samples: 552172
# Current samples: 973364
#
# Continual dataset: ['cic-2018', 'usb-2021']
# Classes: ['benign', 'hulk', 'slowloris', 'slowhttp', 'goldeneye', 'tcpflood']
# cpu
#
# Training phase
# Current malicious class: DoS-Hulk
# ...

# %%
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
